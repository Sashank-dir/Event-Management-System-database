# %%
pip install mysql-connector
# Out:
# Requirement already satisfied: mysql-connector in c:\users\dell\anaconda3\lib\site-packages (2.2.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import mysql.connector

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',  
    'database': 'event_management'
}

# Path to your CSV file
csv_file_path = r'C:\Users\DELL\Downloads\event_management_dataset (1).csv'

# Create MySQL connection
def create_connection():
    try:
        conn = mysql.connector.connect(**mysql_config)
        return conn
    except mysql.connector.Error as err:
        print("Error connecting to MySQL:", err)
        return None

# Batch insert function to handle large datasets
def import_csv_to_mysql_batch(conn, csv_file_path, batch_size=1000):
    if not conn:
        return

    try:
        with open(csv_file_path, 'r') as csv_file:
            csv_reader = csv.DictReader(csv_file)
            cursor = conn.cursor()

            # Prepare the SQL query for batch insertion
            insert_query = """
                INSERT INTO event_management_dataset 
                (EventName, Venue, PaymentStatus, SeatsBooked, TicketPrice, AttendeeName, Email, Phone, RegistrationDate, EventDate) 
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            batch_data = []
            for idx, row in enumerate(csv_reader):
                # Collect the data in batch
                batch_data.append((
                    row['Event Name'], row['Venue'], row['Payment Status'], row['Seats Booked'], 
                    row['Ticket Price'], row['Attendee Name'], row['Email'], row['Phone'], 
                    row['Registration Date'], row['Event Date']
                ))

                # Insert data in batches
                if len(batch_data) >= batch_size:
                    cursor.executemany(insert_query, batch_data)
                    conn.commit()
                    batch_data = []  # Reset batch after insert

            # Insert any remaining rows
            if batch_data:
                cursor.executemany(insert_query, batch_data)
                conn.commit()

            print("CSV data imported successfully in batches!")

    except mysql.connector.Error as err:
        print("Error importing CSV data:", err)

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

if __name__ == "__main__":
    connection = create_connection()
    import_csv_to_mysql_batch(connection, csv_file_path)
# Out:
# CSV data imported successfully in batches!

# %%
import csv
import mysql.connector

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',  
    'database': 'event_management'
}

# Path to your CSV file
csv_file_path = r'C:\Users\DELL\Downloads\event_management_dataset2 (1).csv'

# Create MySQL connection
def create_connection():
    try:
        conn = mysql.connector.connect(**mysql_config)
        return conn
    except mysql.connector.Error as err:
        print("Error connecting to MySQL:", err)
        return None

# Batch insert function to handle large datasets
def import_csv_to_mysql_batch(conn, csv_file_path, batch_size=1000):
    if not conn:
        return

    try:
        with open(csv_file_path, 'r') as csv_file:
            csv_reader = csv.DictReader(csv_file)
            cursor = conn.cursor()

            # Prepare the SQL query for batch insertion
            insert_query = """
                INSERT INTO event_management.event_management_dataset2 
                (EventName, Venue, PaymentStatus, SeatsBooked, TicketPrice, AttendeeName, Email, Phone, RegistrationDate, EventDate) 
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            batch_data = []
            for idx, row in enumerate(csv_reader):
                # Collect the data in batch
                batch_data.append((
                    row['Event Name'], row['Venue'], row['Payment Status'], row['Seats Booked'], 
                    row['Ticket Price'], row['Attendee Name'], row['Email'], row['Phone'], 
                    row['Registration Date'], row['Event Date']
                ))

                # Insert data in batches
                if len(batch_data) >= batch_size:
                    cursor.executemany(insert_query, batch_data)
                    conn.commit()
                    batch_data = []  # Reset batch after insert

            # Insert any remaining rows
            if batch_data:
                cursor.executemany(insert_query, batch_data)
                conn.commit()

            print("CSV data imported successfully in batches!")

    except mysql.connector.Error as err:
        print("Error importing CSV data:", err)

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

if __name__ == "__main__":
    connection = create_connection()
    import_csv_to_mysql_batch(connection, csv_file_path)
# Out:
# CSV data imported successfully in batches!

# %%
import csv
import mysql.connector

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',  
    'database': 'event_management'
}

# Path to your CSV file
csv_file_path = r'C:\Users\DELL\Downloads\event_management_dataset3 (1).csv'

# Create MySQL connection
def create_connection():
    try:
        conn = mysql.connector.connect(**mysql_config)
        return conn
    except mysql.connector.Error as err:
        print("Error connecting to MySQL:", err)
        return None

# Batch insert function to handle large datasets
def import_csv_to_mysql_batch(conn, csv_file_path, batch_size=1000):
    if not conn:
        return

    try:
        with open(csv_file_path, 'r') as csv_file:
            csv_reader = csv.DictReader(csv_file)
            cursor = conn.cursor()

            # Prepare the SQL query for batch insertion
            insert_query = """
                INSERT INTO event_management.event_management_dataset3 
                (EventName, Venue, PaymentStatus, SeatsBooked, TicketPrice, AttendeeName, Email, Phone, RegistrationDate, EventDate) 
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            batch_data = []
            for idx, row in enumerate(csv_reader):
                # Collect the data in batch
                batch_data.append((
                    row['Event Name'], row['Venue'], row['Payment Status'], row['Seats Booked'], 
                    row['Ticket Price'], row['Attendee Name'], row['Email'], row['Phone'], 
                    row['Registration Date'], row['Event Date']
                ))

                # Insert data in batches
                if len(batch_data) >= batch_size:
                    cursor.executemany(insert_query, batch_data)
                    conn.commit()
                    batch_data = []  # Reset batch after insert

            # Insert any remaining rows
            if batch_data:
                cursor.executemany(insert_query, batch_data)
                conn.commit()

            print("CSV data imported successfully in batches!")

    except mysql.connector.Error as err:
        print("Error importing CSV data:", err)

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

if __name__ == "__main__":
    connection = create_connection()
    import_csv_to_mysql_batch(connection, csv_file_path)
# Out:
# CSV data imported successfully in batches!

# %%
import csv
import mysql.connector

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',  
    'database': 'event_management'
}

# Path to your CSV file
csv_file_path = r'C:\Users\DELL\Downloads\event_management_dataset4 (1).csv'

# Create MySQL connection
def create_connection():
    try:
        conn = mysql.connector.connect(**mysql_config)
        return conn
    except mysql.connector.Error as err:
        print("Error connecting to MySQL:", err)
        return None

# Batch insert function to handle large datasets
def import_csv_to_mysql_batch(conn, csv_file_path, batch_size=1000):
    if not conn:
        return

    try:
        with open(csv_file_path, 'r') as csv_file:
            csv_reader = csv.DictReader(csv_file)
            cursor = conn.cursor()

            # Prepare the SQL query for batch insertion
            insert_query = """
                INSERT INTO event_management.event_management_dataset4 
                (EventName, Venue, PaymentStatus, SeatsBooked, TicketPrice, AttendeeName, Email, Phone, RegistrationDate, EventDate) 
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            batch_data = []
            for idx, row in enumerate(csv_reader):
                # Collect the data in batch
                batch_data.append((
                    row['Event Name'], row['Venue'], row['Payment Status'], row['Seats Booked'], 
                    row['Ticket Price'], row['Attendee Name'], row['Email'], row['Phone'], 
                    row['Registration Date'], row['Event Date']
                ))

                # Insert data in batches
                if len(batch_data) >= batch_size:
                    cursor.executemany(insert_query, batch_data)
                    conn.commit()
                    batch_data = []  # Reset batch after insert

            # Insert any remaining rows
            if batch_data:
                cursor.executemany(insert_query, batch_data)
                conn.commit()

            print("CSV data imported successfully in batches!")

    except mysql.connector.Error as err:
        print("Error importing CSV data:", err)

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

if __name__ == "__main__":
    connection = create_connection()
    import_csv_to_mysql_batch(connection, csv_file_path)
# Out:
# CSV data imported successfully in batches!

# %%
import mysql.connector
import time

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',
    'database': 'event_management' 
}

# Connect to MySQL
conn = mysql.connector.connect(**mysql_config)
cursor = conn.cursor()

# MySQL query to fetch event details for a specific attendee based on their email
query = """
SELECT `EventName`, Venue, `PaymentStatus`, `SeatsBooked`, `TicketPrice`, `AttendeeName`, Email, Phone, `RegistrationDate`, `EventDate`
FROM event_management_dataset
WHERE Email = 'pachecoaustin@example.net' 
"""

# Execute the query and measure the execution time
query_times = []
for _ in range(30):
    start_time = time.time()
    cursor.execute(query)
    result = cursor.fetchall()
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MySQL connection
cursor.close()
conn.close()

# Write the execution times to a result file
with open('results_query1_mysql_event250k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]
# [('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24)), ('Networked next generation implementation', 'North Sarah', 'Cancelled', 5, Decimal('97.66'), 'James Becker', 'pachecoaustin@example.net', '+1-378-251-6034', datetime.date(2024, 3, 20), datetime.date(2024, 4, 24))]

# %%
import mysql.connector
import time

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',
    'database': 'event_management' 
}

# Connect to MySQL
conn = mysql.connector.connect(**mysql_config)
cursor = conn.cursor()

# MySQL query to fetch event details for a specific attendee based on their Attendee Name
query = """
SELECT `EventName`, Venue, `PaymentStatus`, `SeatsBooked`, `TicketPrice`, `AttendeeName`, Email, Phone, `RegistrationDate`, `EventDate`
FROM event_management.event_management_dataset2
WHERE AttendeeName = 'Lisa Carlson' 
"""

# Execute the query and measure the execution time
query_times = []
for _ in range(30):
    start_time = time.time()
    cursor.execute(query)
    result = cursor.fetchall()
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MySQL connection
cursor.close()
conn.close()

# Write the execution times to a result file
with open('results_query1_mysql_event500k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]
# [('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1)), ('Front-line incremental analyzer', 'Rachelhaven', 'Pending', 9, Decimal('122.50'), 'Lisa Carlson', 'alexarnold@example.com', '533-453-1825', datetime.date(2024, 6, 9), datetime.date(2024, 8, 27)), ('Decentralized encompassing system engine', 'Davidport', 'Completed', 7, Decimal('139.87'), 'Lisa Carlson', 'jwood@example.net', '+1-960-284-3803x03250', datetime.date(2024, 5, 21), datetime.date(2024, 7, 30)), ('Enhanced attitude-oriented application', 'Port Christopher', 'Completed', 1, Decimal('151.16'), 'Lisa Carlson', 'christopherjackson@example.org', '417-683-1719x938', datetime.date(2024, 4, 27), datetime.date(2024, 7, 1))]

# %%
import mysql.connector
import time

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',
    'database': 'event_management' 
}

# Connect to MySQL
conn = mysql.connector.connect(**mysql_config)
cursor = conn.cursor()

# MySQL query to fetch event details for a specific attendee based on their Venue
query = """
SELECT `EventName`, Venue, `PaymentStatus`, `SeatsBooked`, `TicketPrice`, `AttendeeName`, Email, Phone, `RegistrationDate`, `EventDate`
FROM event_management.event_management_dataset3
WHERE Venue = 'North Jenniferberg' 
"""

# Execute the query and measure the execution time
query_times = []
for _ in range(30):
    start_time = time.time()
    cursor.execute(query)
    result = cursor.fetchall()
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MySQL connection
cursor.close()
conn.close()

# Write the execution times to a result file
with open('results_query1_mysql_event750k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...
# [('Reactive global artificial intelligence', 'North Jenniferberg', 'Pending', 4, Decimal('171.83'), 'Vincent Walker', 'anthonywilliams@example.org', '+1-432-449-2358', datetime.date(2024, 8, 7), datetime.date(2024, 10, 6)), ('Decentralized clear-thinking core', 'North Jenniferberg', 'Completed', 1, Decimal('52.79'), 'Suzanne Little', 'wwilliams@example.org', '001-634-623-4222x249', datetime.date(2024, 2, 22), datetime.date(2024, 3, 2)), ('Front-line mission-critical flexibility', 'North Jenniferberg', 'Completed', 3, Decimal('45.29'), 'Alexandra Smith', 'zbarron@example.com', '(531)332-9395', datetime.date(2024, 7, 27), datetime.date(2024, 10, 10)), ('Re-engineered needs-based service-desk', 'North Jenniferberg', 'Pending', 2, Decimal('101.10'), 'Maria Johnson', 'sherri98@example.com', '001-851-441-3375x2824', datetime.date(2024, 9, 16), datetime.date(2024, 10, 17)), ('Intuitive scalable implementation', 'North Jenniferberg', 'Completed', 4, Decimal('156.03'), 'Matthew Sims', 'mark60@example.org', '001-591-748-5060x068', datetime.date(2024, 7, 6), datetime.date(2024, 8, 2)), ('Intuitive full-range data-warehouse', 'North Jenniferberg', 'Completed', 3, Decimal('97.52'), 'Maria Rich', 'schmidtsandra@example.net', '879.492.2535', datetime.date(2024, 5, 23), datetime.date(2024, 5, 24)), ('Operative multi-tasking task-force', 'North Jenniferberg', 'Completed', 1, Decimal('82.75'), 'Gregory Mooney', 'sarahroberts@example.com', '903.913.0811x126', datetime.date(2024, 2, 24), datetime.date(2024, 4, 2)), ('Persevering zero-defect infrastructure', 'North Jenniferberg', 'Pending', 7, Decimal('47.47'), 'Andrew Park', 'lcruz@example.com', '734.718.6161x4873', datetime.date(2024, 4, 15), datetime.date(2024, 7, 11)), ('Assimilated impactful implementation', 'North Jenniferberg', 'Cancelled', 5, Decimal('29.06'), 'Kenneth Smith', 'gclayton@example.org', '214.747.6469', datetime.date(2024, 8, 10), datetime.date(2024, 10, 28)), ('Focused bottom-line contingency', 'North Jenniferberg', 'Cancelled', 6, Decimal('171.68'), 'Ashley Ford', 'stevenwelch@example.net', '+1-206-578-8767', datetime.date(2024, 1, 1), datetime.date(2024, 1, 21)), ('Versatile intangible function', 'North Jenniferberg', 'Pending', 3, Decimal('78.53'), 'Anna Fletcher', 'david57@example.net', '(672)626-6652x958', datetime.date(2024, 4, 22), datetime.date(2024, 6, 1)), ('Profit-focused mission-critical task-force', 'North Jenniferberg', 'Completed', 7, Decimal('110.49'), 'Jordan Daniels', 'jamie14@example.com', '+1-775-888-8810x840', datetime.date(2024, 1, 25), datetime.date(2024, 3, 9)), ('Polarized content-based portal', 'North Jenniferberg', 'Completed', 7, Decimal('169.26'), 'Alexis Parker', 'susanriddle@example.net', '+1-388-693-7840x10874', datetime.date(2024, 2, 25), datetime.date(2024, 3, 31)), ('Universal dynamic secured line', 'North Jenniferberg', 'Pending', 4, Decimal('56.12'), 'Jason Bailey', 'elizabethscott@example.com', '001-971-252-2221x844', datetime.date(2024, 7, 20), datetime.date(2024, 9, 11)), ('Profit-focused logistical throughput', 'North Jenniferberg', 'Pending', 4, Decimal('196.61'), 'Tyler Villa', 'wsmith@example.com', '(265)991-2666x813', datetime.date(2024, 6, 27), datetime.date(2024, 9, 11)), ('Switchable client-server knowledge user', 'North Jenniferberg', 'Completed', 10, Decimal('93.85'), 'Angela Burgess', 'katieharding@example.com', '322.763.1272', datetime.date(2024, 2, 22), datetime.date(2024, 3, 21)), ('Centralized value-added collaboration', 'North Jenniferberg', 'Completed', 2, Decimal('29.02'), 'Janet Thornton', 'bakertimothy@example.com', '001-392-414-4223x653', datetime.date(2024, 7, 30), datetime.date(2024, 9, 25)), ('Customer-focused needs-based core', 'North Jenniferberg', 'Pending', 5, Decimal('61.23'), 'Corey Thomas', 'prichardson@example.org', '961-251-4542x09935', datetime.date(2024, 9, 5), datetime.date(2024, 11, 10)), ('Multi-tiered mobile productivity', 'North Jenniferberg', 'Cancelled', 7, Decimal('158.81'), 'Brandon Serrano',  ...

# %%
import mysql.connector
import time

# MySQL server configuration
mysql_config = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': 'Sanee@2003',
    'database': 'event_management' 
}

# Connect to MySQL
conn = mysql.connector.connect(**mysql_config)
cursor = conn.cursor()

# MySQL query to fetch event details for a specific attendee based on their Event Name
query = """
SELECT `EventName`, Venue, `PaymentStatus`, `SeatsBooked`, `TicketPrice`, `AttendeeName`, Email, Phone, `RegistrationDate`, `EventDate`
FROM event_management.event_management_dataset4
WHERE EventName = 'Polarized directional knowledge user' 
"""

# Execute the query and measure the execution time
query_times = []
for _ in range(30):
    start_time = time.time()
    cursor.execute(query)
    result = cursor.fetchall()
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MySQL connection
cursor.close()
conn.close()

# Write the execution times to a result file
with open('results_query1_mysql_event1M.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
# [('Polarized directional knowledge user', 'Derekside', 'Pending', 6, Decimal('95.14'), 'Tracy Marsh', 'eedwards@example.com', '833.922.9983x26265', datetime.date(2024, 9, 4), datetime.date(2024, 9, 12))]
