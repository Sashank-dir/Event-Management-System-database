# %%
# !pip install neo4j
# !pip install py2neo
# Out:
# Requirement already satisfied: neo4j in c:\users\dell\anaconda3\lib\site-packages (5.24.0)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\lib\site-packages (from neo4j) (2020.1)
# Requirement already satisfied: py2neo in c:\users\dell\anaconda3\lib\site-packages (2021.2.4)
# Requirement already satisfied: interchange~=2021.0.4 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: urllib3 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (1.25.11)
# Requirement already satisfied: monotonic in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (1.6)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (20.4)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2020.6.20)
# Requirement already satisfied: six>=1.15.0 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (1.15.0)
# Requirement already satisfied: pansi>=2020.7.3 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2.7.2)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\lib\site-packages (from interchange~=2021.0.4->py2neo) (2020.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\dell\anaconda3\lib\site-packages (from packaging->py2neo) (2.4.7)

# %%
import csv
from py2neo import Graph, Node, Relationship
from neo4j import GraphDatabase
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"  # Update this with your actual password

driver = GraphDatabase.driver(uri, auth=(username, password))

query_times = []

# Define the Cypher query to retrieve all Event nodes
cypher_query = (
    "MATCH (e:Event) "
    "RETURN e"  # Return the entire Event node
)

with driver.session() as session:
    # Execute the Cypher query and measure the execution time
    start_time = time.time()
    for _ in range(30):
        result = session.run(cypher_query)
        record = result.single()  # Retrieve a single record from the query result
        if record:
            # Access the Event node (e represents the 'Event' node)
            print(record['e'])  # Print the entire Event node
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)

# Write the execution times to a result file
with open('results_query3_neo4j_event250k.txt', 'w') as result_file:
    result_file.write(f"Query 3 execution times: {query_times}\n")

# Close the Neo4j driver
driver.close()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\neo4j\_sync\work\result.py:604: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>

# %%
import csv
from py2neo import Graph, Node, Relationship
from neo4j import GraphDatabase
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"  # Update this with your actual password

driver = GraphDatabase.driver(uri, auth=(username, password))

query_times = []

# Define the Cypher query to retrieve all Event nodes
cypher_query = (
    "MATCH (e:Event) "
    "RETURN e"  # Return the entire Event node
)

with driver.session() as session:
    # Execute the Cypher query and measure the execution time
    start_time = time.time()
    for _ in range(30):
        result = session.run(cypher_query)
        record = result.single()  # Retrieve a single record from the query result
        if record:
            # Access the Event node (e represents the 'Event' node)
            print(record['e'])  # Print the entire Event node
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)

# Write the execution times to a result file
with open('results_query3_neo4j_event500k.txt', 'w') as result_file:
    result_file.write(f"Query 3 execution times: {query_times}\n")

# Close the Neo4j driver
driver.close()
# Out:
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>

# %%
import csv
from py2neo import Graph, Node, Relationship
from neo4j import GraphDatabase
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"  # Update this with your actual password

driver = GraphDatabase.driver(uri, auth=(username, password))

query_times = []

# Define the Cypher query to retrieve all Event nodes
cypher_query = (
    "MATCH (e:Event) "
    "RETURN e"  # Return the entire Event node
)

with driver.session() as session:
    # Execute the Cypher query and measure the execution time
    start_time = time.time()
    for _ in range(30):
        result = session.run(cypher_query)
        record = result.single()  # Retrieve a single record from the query result
        if record:
            # Access the Event node (e represents the 'Event' node)
            print(record['e'])  # Print the entire Event node
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)

# Write the execution times to a result file
with open('results_query3_neo4j_event750k.txt', 'w') as result_file:
    result_file.write(f"Query 3 execution times: {query_times}\n")

# Close the Neo4j driver
driver.close()
# Out:
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>

# %%
import csv
from py2neo import Graph, Node, Relationship
from neo4j import GraphDatabase
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"  # Update this with your actual password

driver = GraphDatabase.driver(uri, auth=(username, password))

query_times = []

# Define the Cypher query to retrieve all Event nodes
cypher_query = (
    "MATCH (e:Event) "
    "RETURN e"  # Return the entire Event node
)

with driver.session() as session:
    # Execute the Cypher query and measure the execution time
    start_time = time.time()
    for _ in range(30):
        result = session.run(cypher_query)
        record = result.single()  # Retrieve a single record from the query result
        if record:
            # Access the Event node (e represents the 'Event' node)
            print(record['e'])  # Print the entire Event node
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)

# Write the execution times to a result file
with open('results_query3_neo4j_event1M.txt', 'w') as result_file:
    result_file.write(f"Query 3 execution times: {query_times}\n")

# Close the Neo4j driver
driver.close()
# Out:
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
# <Node element_id='4:27a5b7f9-9a92-4d10-94e3-dee6a6bf1caa:0' labels=frozenset({'Event'}) properties={'Registration Date': '2024-08-09 18:13:58.525545', 'Attendee Name': 'Elizabeth Romero', 'Payment Status': 'Completed', 'Email': 'epena@example.com', 'Event Date': '2024-10-19 18:13:58.525545', 'Venue': 'Darrellborough', 'Event Name': 'Reduced high-level website', 'Phone': '(640)375-8056x901', 'Seats Booked': 1, 'Ticket Price': 98.68}>
