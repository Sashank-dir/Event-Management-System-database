# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset (1).csv')
print (dataset)
# Out:
#                                           Event Name                  Venue  \
# 0                         Reduced high-level website         Darrellborough
# 1                     Balanced system-worthy website  West Catherineborough
# 2           Networked next generation implementation            North Sarah
# 3                   Pre-emptive secondary time-frame      East Nancychester
# 4       Team-oriented fault-tolerant instruction set        South Laurabury
# ...                                              ...                    ...
# 249995                          Phased 24/7 extranet             Hermanberg
# 249996   Adaptive analyzing Graphical User Interface            New Spencer
# 249997          Multi-lateral zero-defect time-frame          Martinchester
# 249998           Object-based needs-based middleware        West Travisberg
# 249999  Fully-configurable bandwidth-monitored frame           Ebonychester
#
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"  
collection_name = "250k"

# Query filter and projection for event management
query_filter = {}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Skip and limit values for pagination
start_rank = 0
limit = 10

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find(query_filter, projection).sort(
        "Event Date", -1).skip(start_rank).limit(limit)  # Sorting by Event Date
    for record in result:
        print(record)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query2_mongodb_event250k.txt', 'w') as result_file:
    result_file.write(f"Query 2 execution times: {query_times}\n")
# Out:
# {'Event Name': 'Horizontal radical budgetary management', 'Venue': 'Bradystad', 'Payment Status': 'Completed', 'Seats Booked': 4, 'Ticket Price': 37.74, 'Attendee Name': 'Matthew Freeman', 'Email': 'dmelton@example.net', 'Phone': '001-555-667-9146x807', 'Registration Date': '2024-10-08 08:33:00.353666', 'Event Date': '2025-01-06 08:33:00.353666'}
# {'Event Name': 'Function-based empowering moratorium', 'Venue': 'Davidside', 'Payment Status': 'Completed', 'Seats Booked': 7, 'Ticket Price': 144.92, 'Attendee Name': 'Frank Fowler', 'Email': 'carl93@example.net', 'Phone': 6468271801, 'Registration Date': '2024-10-08 05:37:21.240667', 'Event Date': '2025-01-06 05:37:21.240667'}
# ...

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset2 (1).csv')
print (dataset)
# Out:
#                                           Event Name             Venue  \
# 0          Vision-oriented eco-centric system engine    New Cynthiaton
# 1                Cross-platform web-enabled alliance  North Justinview
# 2                    Front-line incremental analyzer       Rachelhaven
# 3                    Versatile user-facing migration        Davidville
# 4                     Synergized national initiative           Lisaton
# ...                                              ...               ...
# 499995                Cloned full-range productivity      Lake Charles
# 499996  Profit-focused zero administration moderator          Ryanview
# 499997                 Phased user-facing complexity      Gonzalezstad
# 499998          Horizontal client-server methodology       North James
# 499999             Phased system-worthy architecture   Lake Johnnyfort
#
#        Payment Status  Seats Booked  Ticket Price       Attendee Name  \
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"  
collection_name = "500k"

# Query filter and projection for event management
query_filter = {}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Skip and limit values for pagination
start_rank = 0
limit = 10

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find(query_filter, projection).sort(
        "Event Date", -1).skip(start_rank).limit(limit)  # Sorting by Event Date
    for record in result:
        print(record)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query2_mongodb_event500k.txt', 'w') as result_file:
    result_file.write(f"Query 2 execution times: {query_times}\n")
# Out:
# {'Event Name': 'De-engineered scalable help-desk', 'Venue': 'Ferrellland', 'Payment Status': 'Pending', 'Seats Booked': 5, 'Ticket Price': 34.06, 'Attendee Name': 'Christina Barber', 'Email': 'chloe81@example.com', 'Phone': '629.675.5565x61096', 'Registration Date': '2024-10-08 10:03:37.974893', 'Event Date': '2025-01-06 10:03:37.974893'}
# {'Event Name': 'Mandatory national approach', 'Venue': 'Christinamouth', 'Payment Status': 'Cancelled', 'Seats Booked': 10, 'Ticket Price': 185.77, 'Attendee Name': 'Sandra Stout', 'Email': 'taylorjennifer@example.net', 'Phone': '993.653.5815x829', 'Registration Date': '2024-10-08 07:52:53.721306', 'Event Date': '2025-01-06 07:52:53.721306'}
# ...

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset3 (1).csv')
print (dataset)
# Out:
#                                            Event Name                Venue  \
# 0                   Innovative multimedia utilization      East Brookeport
# 1                   Optional full-range system engine         Samanthaland
# 2             Reactive global artificial intelligence   North Jenniferberg
# 3       Balanced leadingedge Graphical User Interface          South Logan
# 4                      Organic disintermediate policy             Choifurt
# ...                                               ...                  ...
# 749995           Cross-platform foreground neural-net           Mooreshire
# 749996      Multi-lateral disintermediate application          East Daniel
# 749997              Integrated homogeneous encryption         West Zachary
# 749998         Triple-buffered client-server approach  North Veronicamouth
# 749999             Visionary motivating knowledgebase     North Justinview
#
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"  
collection_name = "750k"

# Query filter and projection for event management
query_filter = {}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Skip and limit values for pagination
start_rank = 0
limit = 10

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find(query_filter, projection).sort(
        "Event Date", -1).skip(start_rank).limit(limit)  # Sorting by Event Date
    for record in result:
        print(record)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query2_mongodb_event750k.txt', 'w') as result_file:
    result_file.write(f"Query 2 execution times: {query_times}\n")
# Out:
# {'Event Name': 'Reduced human-resource time-frame', 'Venue': 'West Evelyn', 'Payment Status': 'Completed', 'Seats Booked': 6, 'Ticket Price': 64.33, 'Attendee Name': 'Shawn Sullivan', 'Email': 'perezjacqueline@example.com', 'Phone': 7723567839, 'Registration Date': '2024-10-08 11:06:24.326869', 'Event Date': '2025-01-06 11:06:24.326869'}
# {'Event Name': 'Optimized asynchronous support', 'Venue': 'West Jeffrey', 'Payment Status': 'Cancelled', 'Seats Booked': 6, 'Ticket Price': 38.27, 'Attendee Name': 'Steven Jenkins II', 'Email': 'sawyermichelle@example.net', 'Phone': '+1-743-761-4185', 'Registration Date': '2024-10-08 10:29:46.175628', 'Event Date': '2025-01-06 10:29:46.175628'}
# ...

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset4 (1).csv')
print (dataset)
# Out:
#                                        Event Name              Venue  \
# 0               Realigned next generation circuit          Davisstad
# 1                Customer-focused radical adapter         Molinaland
# 2            Polarized directional knowledge user          Derekside
# 3           Multi-lateral fault-tolerant function        Aguilarport
# 4           Future-proofed uniform data-warehouse  Port Nicholastown
# ...                                           ...                ...
# 999995       Decentralized responsive methodology       Brandonhaven
# 999996                Stand-alone real-time array       Port Randall
# 999997  Function-based non-volatile knowledgebase        East Andrew
# 999998            Multi-tiered exuding throughput        South David
# 999999  Cross-platform context-sensitive leverage           New Alan
#
#        Payment Status  Seats Booked  Ticket Price          Attendee Name  \
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"  
collection_name = "1M"

# Query filter and projection for event management
query_filter = {}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Skip and limit values for pagination
start_rank = 0
limit = 10

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find(query_filter, projection).sort(
        "Event Date", -1).skip(start_rank).limit(limit)  # Sorting by Event Date
    for record in result:
        print(record)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query2_mongodb_event1M.txt', 'w') as result_file:
    result_file.write(f"Query 2 execution times: {query_times}\n")
# Out:
# {'Event Name': 'Business-focused motivating knowledgebase', 'Venue': 'Julieport', 'Payment Status': 'Pending', 'Seats Booked': 8, 'Ticket Price': 194.37, 'Attendee Name': 'Catherine Turner', 'Email': 'jmartin@example.net', 'Phone': '+1-738-251-4774x072', 'Registration Date': '2024-10-08 11:39:02.006734', 'Event Date': '2025-01-06 11:39:02.006734'}
# {'Event Name': 'Assimilated intangible encoding', 'Venue': 'Blackshire', 'Payment Status': 'Completed', 'Seats Booked': 4, 'Ticket Price': 63.03, 'Attendee Name': 'Lauren Bennett', 'Email': 'melaniephillips@example.org', 'Phone': '(946)380-1864', 'Registration Date': '2024-10-08 09:52:08.568910', 'Event Date': '2025-01-06 09:52:08.568910'}
# ...
