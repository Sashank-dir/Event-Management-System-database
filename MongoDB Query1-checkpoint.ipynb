# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset (1).csv')
print (dataset)
# Out:
#                                           Event Name                  Venue  \
# 0                         Reduced high-level website         Darrellborough
# 1                     Balanced system-worthy website  West Catherineborough
# 2           Networked next generation implementation            North Sarah
# 3                   Pre-emptive secondary time-frame      East Nancychester
# 4       Team-oriented fault-tolerant instruction set        South Laurabury
# ...                                              ...                    ...
# 249995                          Phased 24/7 extranet             Hermanberg
# 249996   Adaptive analyzing Graphical User Interface            New Spencer
# 249997          Multi-lateral zero-defect time-frame          Martinchester
# 249998           Object-based needs-based middleware        West Travisberg
# 249999  Fully-configurable bandwidth-monitored frame           Ebonychester
#
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"
collection_name = "250k"

# Query filter to search for a specific event (e.g., by Event Name)
query_filter = {"Event Name": "Networked next generation implementation"}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find_one(query_filter, projection)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query1_mongodb_event250k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# {'Event Name': 'Networked next generation implementation', 'Venue': 'North Sarah', 'Payment Status': 'Cancelled', 'Seats Booked': 5, 'Ticket Price': 97.66, 'Attendee Name': 'James Becker', 'Email': 'pachecoaustin@example.net', 'Phone': '+1-378-251-6034', 'Registration Date': '2024-03-20 23:32:10.499627', 'Event Date': '2024-04-24 23:32:10.499627'}
# {'Event Name': 'Networked next generation implementation', 'Venue': 'North Sarah', 'Payment Status': 'Cancelled', 'Seats Booked': 5, 'Ticket Price': 97.66, 'Attendee Name': 'James Becker', 'Email': 'pachecoaustin@example.net', 'Phone': '+1-378-251-6034', 'Registration Date': '2024-03-20 23:32:10.499627', 'Event Date': '2024-04-24 23:32:10.499627'}
# ...

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset2 (1).csv')
print (dataset)
# Out:
#                                           Event Name             Venue  \
# 0          Vision-oriented eco-centric system engine    New Cynthiaton
# 1                Cross-platform web-enabled alliance  North Justinview
# 2                    Front-line incremental analyzer       Rachelhaven
# 3                    Versatile user-facing migration        Davidville
# 4                     Synergized national initiative           Lisaton
# ...                                              ...               ...
# 499995                Cloned full-range productivity      Lake Charles
# 499996  Profit-focused zero administration moderator          Ryanview
# 499997                 Phased user-facing complexity      Gonzalezstad
# 499998          Horizontal client-server methodology       North James
# 499999             Phased system-worthy architecture   Lake Johnnyfort
#
#        Payment Status  Seats Booked  Ticket Price       Attendee Name  \
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"
collection_name = "500k"

# Query filter to search for a specific event (e.g., by Event Name)
query_filter = {"Event Name": "Synergized national initiative"}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find_one(query_filter, projection)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query1_mongodb_event500k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# {'Event Name': 'Synergized national initiative', 'Venue': 'Lisaton', 'Payment Status': 'Cancelled', 'Seats Booked': 5, 'Ticket Price': 115.96, 'Attendee Name': 'Megan Welch', 'Email': 'hdodson@example.net', 'Phone': '(636)389-8981x9373', 'Registration Date': '2024-03-03 23:32:11.144807', 'Event Date': '2024-04-15 23:32:11.144807'}
# {'Event Name': 'Synergized national initiative', 'Venue': 'Lisaton', 'Payment Status': 'Cancelled', 'Seats Booked': 5, 'Ticket Price': 115.96, 'Attendee Name': 'Megan Welch', 'Email': 'hdodson@example.net', 'Phone': '(636)389-8981x9373', 'Registration Date': '2024-03-03 23:32:11.144807', 'Event Date': '2024-04-15 23:32:11.144807'}
# ...

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset3 (1).csv')
print (dataset)
# Out:
#                                            Event Name                Venue  \
# 0                   Innovative multimedia utilization      East Brookeport
# 1                   Optional full-range system engine         Samanthaland
# 2             Reactive global artificial intelligence   North Jenniferberg
# 3       Balanced leadingedge Graphical User Interface          South Logan
# 4                      Organic disintermediate policy             Choifurt
# ...                                               ...                  ...
# 749995           Cross-platform foreground neural-net           Mooreshire
# 749996      Multi-lateral disintermediate application          East Daniel
# 749997              Integrated homogeneous encryption         West Zachary
# 749998         Triple-buffered client-server approach  North Veronicamouth
# 749999             Visionary motivating knowledgebase     North Justinview
#
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"
collection_name = "750k"

# Query filter to search for a specific event (e.g., by Event Name)
query_filter = {"Event Name": "Organic disintermediate policy"}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find_one(query_filter, projection)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query1_mongodb_event750k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# {'Event Name': 'Organic disintermediate policy', 'Venue': 'Choifurt', 'Payment Status': 'Pending', 'Seats Booked': 5, 'Ticket Price': 170.16, 'Attendee Name': 'Brandon Adams', 'Email': 'cassiejones@example.net', 'Phone': '451.475.4270', 'Registration Date': '2024-01-10 12:09:51.283839', 'Event Date': '2024-01-15 12:09:51.283839'}
# {'Event Name': 'Organic disintermediate policy', 'Venue': 'Choifurt', 'Payment Status': 'Pending', 'Seats Booked': 5, 'Ticket Price': 170.16, 'Attendee Name': 'Brandon Adams', 'Email': 'cassiejones@example.net', 'Phone': '451.475.4270', 'Registration Date': '2024-01-10 12:09:51.283839', 'Event Date': '2024-01-15 12:09:51.283839'}
# ...

# %%
import pandas as pd

dataset = pd.read_csv('Downloads/event_management_dataset4 (1).csv')
print (dataset)
# Out:
#                                        Event Name              Venue  \
# 0               Realigned next generation circuit          Davisstad
# 1                Customer-focused radical adapter         Molinaland
# 2            Polarized directional knowledge user          Derekside
# 3           Multi-lateral fault-tolerant function        Aguilarport
# 4           Future-proofed uniform data-warehouse  Port Nicholastown
# ...                                           ...                ...
# 999995       Decentralized responsive methodology       Brandonhaven
# 999996                Stand-alone real-time array       Port Randall
# 999997  Function-based non-volatile knowledgebase        East Andrew
# 999998            Multi-tiered exuding throughput        South David
# 999999  Cross-platform context-sensitive leverage           New Alan
#
#        Payment Status  Seats Booked  Ticket Price          Attendee Name  \
# ...

# %%
from pymongo import MongoClient
import time

# MongoDB connection settings
mongodb_uri = "mongodb://localhost:27017/"
database_name = "Event_management"
collection_name = "1M"

# Query filter to search for a specific event (e.g., by Event Name)
query_filter = {"Event Name": "Future-proofed uniform data-warehouse"}
projection = {
    "Event Name": 1,
    "Event Date": 1,
    "Venue": 1,
    "Attendee Name": 1,
    "Email": 1,
    "Phone": 1,
    "Registration Date": 1,
    "Ticket Price": 1,
    "Seats Booked": 1,
    "Payment Status": 1,
    "_id": 0,
}

# Connect to MongoDB
client = MongoClient(mongodb_uri)
db = client[database_name]
collection = db[collection_name]

query_times = []

# Retrieve event information from MongoDB and measure the execution time
for _ in range(30):
    start_time = time.time()
    result = collection.find_one(query_filter, projection)
    end_time = time.time()
    execution_time = end_time - start_time
    query_times.append(execution_time)
    print(result)

# Close the MongoDB connection
client.close()

# Write the execution times to a result file
with open('results_query1_mongodb_event1M.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
# Out:
# {'Event Name': 'Future-proofed uniform data-warehouse', 'Venue': 'Port Nicholastown', 'Payment Status': 'Cancelled', 'Seats Booked': 10, 'Ticket Price': 24.27, 'Attendee Name': 'Dr. Tyler Ware', 'Email': 'gwoodward@example.com', 'Phone': '001-268-396-8944', 'Registration Date': '2024-05-10 12:34:47.812799', 'Event Date': '2024-07-25 12:34:47.812799'}
# {'Event Name': 'Future-proofed uniform data-warehouse', 'Venue': 'Port Nicholastown', 'Payment Status': 'Cancelled', 'Seats Booked': 10, 'Ticket Price': 24.27, 'Attendee Name': 'Dr. Tyler Ware', 'Email': 'gwoodward@example.com', 'Phone': '001-268-396-8944', 'Registration Date': '2024-05-10 12:34:47.812799', 'Event Date': '2024-07-25 12:34:47.812799'}
# ...
