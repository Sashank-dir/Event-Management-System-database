# %%
# !pip install neo4j
# !pip install py2neo
# Out:
# Requirement already satisfied: neo4j in c:\users\dell\anaconda3\lib\site-packages (5.24.0)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\lib\site-packages (from neo4j) (2020.1)
# Requirement already satisfied: py2neo in c:\users\dell\anaconda3\lib\site-packages (2021.2.4)
# Requirement already satisfied: six>=1.15.0 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (1.15.0)
# Requirement already satisfied: urllib3 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (1.25.11)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2020.6.20)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (20.4)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2.7.2)
# Requirement already satisfied: monotonic in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (1.6)
# Requirement already satisfied: interchange~=2021.0.4 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: pansi>=2020.7.3 in c:\users\dell\anaconda3\lib\site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\dell\anaconda3\lib\site-packages (from packaging->py2neo) (2.4.7)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\lib\site-packages (from interchange~=2021.0.4->py2neo) (2020.1)

# %%
import csv
from py2neo import Graph
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"

graph = Graph(uri, auth=(username, password))

# Define the Cypher query to retrieve an event's information
cypher_query = (
    "MATCH (e:Event_250k {event_id: 'event123'}) "
    "RETURN e.event_name AS event_name, e.venue AS venue, e.payment_status AS payment_status, "
    "e.seats_booked AS seats_booked, e.ticket_price AS ticket_price, e.attendee_name AS attendee_name, "
    "e.attendee_email AS attendee_email, e.attendee_phone AS attendee_phone, "
    "e.registration_date AS registration_date, e.event_date AS event_date"
)

query_times = []
results = []

# Retrieve an event's information from Neo4j and measure the execution time
for _ in range(30):
    try:
        start_time = time.time()
        result = graph.run(cypher_query).data()  # Fetch as list of dictionaries
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)
        results.append(result)  # Collect the result for each iteration throughout the loop
    except Exception as e:
        print(f"An error occurred: {e}")

# Write the execution times and results to a result file
with open('results_query1_neo4j_event250k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")

# %%
import csv
from py2neo import Graph
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"

graph = Graph(uri, auth=(username, password))

# Define the Cypher query to retrieve an event's information
cypher_query = (
    "MATCH (e:Event_500k {event_id: 'event123'}) "
    "RETURN e.event_name AS event_name, e.venue AS venue, e.payment_status AS payment_status, "
    "e.seats_booked AS seats_booked, e.ticket_price AS ticket_price, e.attendee_name AS attendee_name, "
    "e.attendee_email AS attendee_email, e.attendee_phone AS attendee_phone, "
    "e.registration_date AS registration_date, e.event_date AS event_date"
)

query_times = []
results = []

# Retrieve an event's information from Neo4j and measure the execution time
for _ in range(30):
    try:
        start_time = time.time()
        result = graph.run(cypher_query).data()  # Fetch as list of dictionaries
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)
        results.append(result)  # Collect the result for each iteration
    except Exception as e:
        print(f"An error occurred: {e}")

# Write the execution times and results to a result file
with open('results_query1_neo4j_event500k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")

# %%
import csv
from py2neo import Graph
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"

graph = Graph(uri, auth=(username, password))

# Define the Cypher query to retrieve an event's information
cypher_query = (
    "MATCH (e:Event_750k {event_id: 'event123'}) "
    "RETURN e.event_name AS event_name, e.venue AS venue, e.payment_status AS payment_status, "
    "e.seats_booked AS seats_booked, e.ticket_price AS ticket_price, e.attendee_name AS attendee_name, "
    "e.attendee_email AS attendee_email, e.attendee_phone AS attendee_phone, "
    "e.registration_date AS registration_date, e.event_date AS event_date"
)

query_times = []
results = []

# Retrieve an event's information from Neo4j and measure the execution time
for _ in range(30):
    try:
        start_time = time.time()
        result = graph.run(cypher_query).data()  # Fetch as list of dictionaries
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)
        results.append(result)  # Collect the result for each iteration
    except Exception as e:
        print(f"An error occurred: {e}")

# Write the execution times and results to a result file
with open('results_query1_neo4j_event750k.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")

# %%
import csv
from py2neo import Graph
import time

# Connect to your Neo4j instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "Sanee@2003"

graph = Graph(uri, auth=(username, password))

# Define the Cypher query to retrieve an event's information
cypher_query = (
    "MATCH (e:Event_1M {event_id: 'event123'}) "
    "RETURN e.event_name AS event_name, e.venue AS venue, e.payment_status AS payment_status, "
    "e.seats_booked AS seats_booked, e.ticket_price AS ticket_price, e.attendee_name AS attendee_name, "
    "e.attendee_email AS attendee_email, e.attendee_phone AS attendee_phone, "
    "e.registration_date AS registration_date, e.event_date AS event_date"
)

query_times = []
results = []

# Retrieve an event's information from Neo4j and measure the execution time
for _ in range(30):
    try:
        start_time = time.time()
        result = graph.run(cypher_query).data()  # Fetch as list of dictionaries
        end_time = time.time()
        execution_time = end_time - start_time
        query_times.append(execution_time)
        results.append(result)  # Collect the result for each iteration
    except Exception as e:
        print(f"An error occurred: {e}")

# Write the execution times and results to a result file
with open('results_query1_neo4j_event1M.txt', 'w') as result_file:
    result_file.write(f"Query 1 execution times: {query_times}\n")
